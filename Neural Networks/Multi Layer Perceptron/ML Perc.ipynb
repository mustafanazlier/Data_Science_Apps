# %% [markdown]
# # Neural Network Homework-2  Mustafa Nazlıer

# %% [markdown]
# ## Q1)

# %% [markdown]
# ### Neural network using Sigmoid activation function

# %%
import matplotlib.pyplot as plt
import numpy as np

                                            
train_data_sigmoid = np.array(               #inputs for sigmoid
    [
        [0, 0],
        [0, 1],
        [1, 0],
        [1, 1]])
                                            
target_xor_sigmoid = np.array(              #classification of points for sigmoid(0,1) 
    [
        [0],
        [1],
        [1],
        [0]])

# %%
weights01_Sigmoid = np.array([[5.7, 3.7],  [5.8, 3.7]])  #I have found these weights by running some sample neural network for xor problem
weights12_Sigmoid = np.array([[ 7.5],[-8]])              #then getting the last updated weights from that neural network, then I tried to 
                                                 #simplify/round them, I have to mention that as expected the outputs were far better with the 
                                                 #weights(same weights but with float values like 8.46455152) that obtained with training

# - b01: biases for the  hidden layer
# - b12: bias for the output layer
bias01_Sigmoid = np.array([[-2.4, -5.7]])
bias12_Sigmoid = np.array([[-3.4]])

# %%
def mySigmoid(x):
    
    return 1 / (1 + np.exp(-x))             #The sigmoid activation function.

def NetworkSigmoid(point):
  
    hiddenLayer1_Sigmoid= np.dot(point, weights01_Sigmoid) + bias01_Sigmoid
    hiddenOut1_Sigmoid = mySigmoid(hiddenLayer1_Sigmoid)
                                                            #My network with sigmoid activation func
    myOutput1_Sigmoid = np.dot(hiddenOut1_Sigmoid, weights12_Sigmoid) + bias12_Sigmoid
    myFinalOutput1_Sigmoid= mySigmoid(myOutput1_Sigmoid)
    
    return myFinalOutput1_Sigmoid

def classifySigmoid(datapoint):
    
     datapoint = np.transpose(datapoint)
     if NetworkSigmoid(datapoint) >= 0.5:
         return 1

     return 0

# %%
OutputSigmoid = NetworkSigmoid(train_data_sigmoid)

OutputSigmoid
# Out:
# array([[0.05716857],
#        [0.94805173],
#        [0.94682836],
#        [0.06506348]])

# %%
plt.figure(figsize=(10, 10))

plt.axis('scaled')
plt.xlim(-5, 5)
plt.ylim(-5, 5)

colors = {
    0: "ro",
    1: "go"
}

# plotting the four datapoints
for i in range(len(train_data_sigmoid)):
    plt.plot([train_data_sigmoid[i][0]],
             [train_data_sigmoid[i][1]],
             colors[target_xor_sigmoid[i][0]],
             markersize=20)

x_range = np.arange(-5, 5, 0.1)
y_range = np.arange(-5, 5, 0.1)

# creating a mesh to plot decision boundary
xx, yy = np.meshgrid(x_range, y_range, indexing='ij')
Z = np.array([[classifySigmoid([x, y]) for x in x_range] for y in y_range])

# using the contourf function to create the plot
plt.contourf(xx, yy, Z, colors=['red', 'green', 'green', 'blue'], alpha=0.4)

# %% [markdown]
# ### Neural network using Tanh activation function

# %%
train_data_tanh = np.array(                    #inputs for tanh
    [                                      
        [-1, -1],
        [-1, 1],
        [1, -1],
        [1, 1]])

target_xor_tanh = np.array(                   #classification of points for tanh(1,-1)
    [
        [-1],
        [1],
        [1],
        [-1]])

                                        
def myTanh(x):
                                             #Tanh activation function.
    return np.tanh(x)

# %%
   

weights01_tanh = np.array([[1.6, 1.8], [1.6, 1.8]])  
weights12_tanh = np.array([[-2.9], [ 2.9]])
                                                    #I have obtained these weights by running some sample neural network for xor problem
                                                    #then getting the last updated weights from that neural network, then I tried to
                                                    #simplify/round them, I have to mention that as expected the outputs were far better with the
                                                    #weights(same weights but with float values like 8.46455152) that obtained with training

bias01_tanh = np.array([[-1.4,  1.7]])
bias12_tanh = np.array([[-2.7]])



def NetworkTanh(point):
  
    hiddenLayer1_tanh= np.dot(point, weights01_tanh) + bias01_tanh
    hiddenOut1_tanh = myTanh(hiddenLayer1_tanh)
                                                           #My network with tanh activation func
    myOutput1_tanh = np.dot(hiddenOut1_tanh, weights12_tanh) + bias12_tanh
    myFinalOutput1_tanh= myTanh(myOutput1_tanh)
    
    return myFinalOutput1_tanh


def classifyTanh(datapoint):
    
     datapoint = np.transpose(datapoint)
     if NetworkTanh(datapoint) >= 0:
         return 1

     return -1

# %%
OutputTanh = NetworkTanh(train_data_tanh)
OutputTanh
# Out:
# array([[-0.98843764],
#        [ 0.98858684],
#        [ 0.98858684],
#        [-0.98778078]])

# %%
plt.figure(figsize=(10, 10))

plt.axis('scaled')
plt.xlim(-5, 5)
plt.ylim(-5, 5)

colors = {
    -1: "ro",
    1: "go"
}

# plotting the four datapoints
for i in range(len(train_data_tanh)):
    plt.plot([train_data_tanh[i][0]],
             [train_data_tanh[i][1]],
             colors[target_xor_tanh[i][0]],
             markersize=20)

x_range = np.arange(-5, 5, 0.1)
y_range = np.arange(-5, 5, 0.1)

# creating a mesh to plot decision boundary
xx, yy = np.meshgrid(x_range, y_range, indexing='ij')
Z = np.array([[classifyTanh([x, y]) for x in x_range] for y in y_range])

# using the contourf function to create the plot
plt.contourf(xx, yy, Z, colors=['red', 'green', 'green', 'blue'], alpha=0.4)

# %%
from IPython.display import Image     #Network topologies for my neural networks 
Image(filename='topologies.png')

# %% [markdown]
# # Q2)

# %% [markdown]
# ##### For the question 2, I had no problem with printing the  decision surfaces for output layers of the both neural networks, but for the hidden layer nodes, I had to use the same neural network functions with different return values (return Hidden Layer Node 1 output etc.). So this resulted in a unnecessarily long question 2, but I didn't know how to implement otherwise

# %% [markdown]
# ## 2.1) Decision Surfaces for Tanh

# %% [markdown]
# ### Decision Surface for Output Layer with Tanh

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(20, 10)) 

x_range = np.arange(-2, 2, 0.1)
y_range = np.arange(-2, 2, 0.1)

# creating a mesh to plot decision boundary
xx, yy = np.meshgrid(x_range, y_range, indexing='ij')
Z = np.array([[classifyTanh([x, y]) for x in x_range] for y in y_range])


# Plot the surface.
surf = ax.plot_surface(xx, yy, Z,
                       linewidth=0, antialiased=True)

# Customize the z axis.
ax.set_zlim(-1, 2)
ax.zaxis.set_major_locator(LinearLocator(20))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')


plt.show()

# %% [markdown]
# ### Decision Surface for Hidden Layer Node 1 with Tanh

# %%
def NetworkTanh1(point):
  
    hiddenLayer1_tanh= np.dot(point, weights01_tanh) + bias01_tanh
    hiddenOut1_tanh = myTanh(hiddenLayer1_tanh)
                                                           #My network with tanh activation func
    
    return hiddenOut1_tanh[:,0]                          ##return Tanh hiddenlayer node 1


def classifyTanh1(datapoint):
    
     datapoint = np.transpose(datapoint)
     if NetworkTanh1(datapoint) >= 0:
         return 1

     return -1

fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(20, 10)) 




x_range = np.arange(-2, 2, 0.1)
y_range = np.arange(-2, 2, 0.1)

# creating a mesh to plot decision boundary
xx, yy = np.meshgrid(x_range, y_range, indexing='ij')
Z = np.array([[classifyTanh1([x, y]) for x in x_range] for y in y_range])


# Plot the surface.
surf = ax.plot_surface(xx, yy, Z,
                       linewidth=0, antialiased=True)

# Customize the z axis.
ax.set_zlim(-1, 2)
ax.zaxis.set_major_locator(LinearLocator(20))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')



plt.show()

# %% [markdown]
# ### Decision Surface for Hidden Layer Node 2 with Tanh

# %%
def NetworkTanh2(point):
  
    hiddenLayer1_tanh= np.dot(point, weights01_tanh) + bias01_tanh
    hiddenOut1_tanh = myTanh(hiddenLayer1_tanh)
     
    return hiddenOut1_tanh[:,1]          #return Tanh hiddenlayer node 2


def classifyTanh2(datapoint):
    
     datapoint = np.transpose(datapoint)
     if NetworkTanh2(datapoint) >= 0:
         return 1

     return -1

fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(20, 10)) 




x_range = np.arange(-2, 2, 0.1)
y_range = np.arange(-2, 2, 0.1)

# creating a mesh to plot decision boundary
xx, yy = np.meshgrid(x_range, y_range, indexing='ij')
Z = np.array([[classifyTanh2([x, y]) for x in x_range] for y in y_range])


# Plot the surface.
surf = ax.plot_surface(xx, yy, Z,
                       linewidth=0, antialiased=True)

# Customize the z axis.
ax.set_zlim(-1, 2)
ax.zaxis.set_major_locator(LinearLocator(20))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')



plt.show()

# %% [markdown]
# ## 2.1) Decision Surfaces for Sigmoid

# %% [markdown]
# ### Decision Surface for Output Layer with Sigmoid

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(20, 10)) 




x_range = np.arange(-2, 2, 0.1)
y_range = np.arange(-2, 2, 0.1)

# creating a mesh to plot decision boundary
xx, yy = np.meshgrid(x_range, y_range, indexing='ij')
Z1 = np.array([[classifySigmoid([x, y]) for x in x_range] for y in y_range])



# Plot the surface.
surf = ax.plot_surface(xx, yy, Z1,
                       linewidth=0, antialiased=True)

# Customize the z axis.
ax.set_zlim(0, 1.5)                         
ax.zaxis.set_major_locator(LinearLocator(20))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')



plt.show()

# %% [markdown]
# ### Decision Surface for Hidden Layer Node 1 with Sigmoid

# %%
def NetworkSigmoid1(point):
  
    hiddenLayer1_Sigmoid= np.dot(point, weights01_Sigmoid) + bias01_Sigmoid
    hiddenOut1_Sigmoid = mySigmoid(hiddenLayer1_Sigmoid)
                                                            #My network with sigmoid activation func
    
    return hiddenOut1_Sigmoid[:,0]                   #return Sigmoid hiddenlayer node 1

def classifySigmoid1(datapoint):
    
     datapoint = np.transpose(datapoint)
     if NetworkSigmoid1(datapoint) >= 0.5:
         return 1

     return 0

fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(20, 10)) 




x_range = np.arange(-2, 2, 0.1)
y_range = np.arange(-2, 2, 0.1)

# creating a mesh to plot decision boundary
xx, yy = np.meshgrid(x_range, y_range, indexing='ij')
Z1 = np.array([[classifySigmoid1([x, y]) for x in x_range] for y in y_range])



# Plot the surface.
surf = ax.plot_surface(xx, yy, Z1,
                       linewidth=0, antialiased=True)

# Customize the z axis.
ax.set_zlim(0, 1.5)
ax.zaxis.set_major_locator(LinearLocator(20))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')



plt.show()

# %% [markdown]
# ### Decision Surface for Hidden Layer Node 2 with Sigmoid

# %%
def NetworkSigmoid2(point):
  
    hiddenLayer1_Sigmoid= np.dot(point, weights01_Sigmoid) + bias01_Sigmoid
    hiddenOut1_Sigmoid = mySigmoid(hiddenLayer1_Sigmoid)
                                                            #My network with sigmoid activation func
    
    return hiddenOut1_Sigmoid[:,1]   #return Sigmoid hiddenlayer node 2

def classifySigmoid2(datapoint):
    
     datapoint = np.transpose(datapoint)
     if NetworkSigmoid2(datapoint) >= 0.5:
         return 1

     return 0

fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(20, 10)) 




x_range = np.arange(-2, 2, 0.1)
y_range = np.arange(-2, 2, 0.1)

# creating a mesh to plot decision boundary
xx, yy = np.meshgrid(x_range, y_range, indexing='ij')
Z1 = np.array([[classifySigmoid2([x, y]) for x in x_range] for y in y_range])



# Plot the surface.
surf = ax.plot_surface(xx, yy, Z1,
                       linewidth=0, antialiased=True)

# Customize the z axis.
ax.set_zlim(0, 1.5)
ax.zaxis.set_major_locator(LinearLocator(20))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')



plt.show()
